# %%
import re
DATA = """
北海道
青森県
岩手県
宮城県
秋田県
山形県
福島県
茨城県
栃木県
群馬県
埼玉県
千葉県
東京都
神奈川県
新潟県
富山県
石川県
福井県
山梨県
長野県
岐阜県
静岡県
愛知県
三重県
滋賀県
京都府
大阪府
兵庫県
奈良県
和歌山県
鳥取県
島根県
岡山県
広島県
山口県
徳島県
香川県
愛媛県
高知県
福岡県
佐賀県
長崎県
熊本県
大分県
宮崎県
鹿児島県
沖縄県
"""

prefecture = re.findall(r'(\w+)\n',DATA)
print(prefecture)
# Out:
# ['北海道', '青森県', '岩手県', '宮城県', '秋田県', '山形県', '福島県', '茨城県', '栃木県', '群馬県', '埼玉県', '千葉県', '東京都', '神奈川県', '新潟県', '富山県', '石川県', '福井県', '山梨県', '長野県', '岐阜県', '静岡県', '愛知県', '三重県', '滋賀県', '京都府', '大阪府', '兵庫県', '奈良県', '和歌山県', '鳥取県', '島根県', '岡山県', '広島県', '山口県', '徳島県', '香川県', '愛媛県', '高知県', '福岡県', '佐賀県', '長崎県', '熊本県', '大分県', '宮崎県', '鹿児島県', '沖縄県']

# %%
#requirement: pip install jusho
from jusho import Jusho
postman = Jusho()
prefectures = ['北海道', '青森県', '岩手県', '宮城県', '秋田県', '山形県', '福島県', '茨城県', '栃木県', '群馬県', '埼玉県', '千葉県', '東京都', '神奈川県', '新潟県', '富山県', '石川県', '福井県', '山梨県', '長野県', '岐阜県', '静岡県', '愛知県', '三重県', '滋賀県', '京都府', '大阪府', '兵庫県', '奈良県', '和歌山県', '鳥取県', '島根県', '岡山県', '広島県', '山口県', '徳島県', '香川県', '愛媛県', '高知県', '福岡県', '佐賀県', '長崎県', '熊本県', '大分県', '宮崎県', '鹿児島県', '沖縄県']
print(len(prefectures))

dic = {}
for pref in prefectures:
    cities = postman.cities_from_prefecture(pref,'kanji')
    #print(cities)
    for city_info in cities:
        city = city_info[1]
        #print(city)
        town_info = postman.towns_from_city(pref,city,'kanji')
        #print(type(town_info))
        for ele in town_info:
            local_name =  city + ele.town_area_kanji.split('（')[0]
            dic[local_name] = pref
    
def prefecture(string):
    for i in range(2,len(string)):
        tmp_str = string[:i]
        if tmp_str in dic.keys():
            return dic[tmp_str]

import pandas as pd 

df = pd.read_csv("basic_info.csv")
df['都道府県名'] = df['所在地'].apply(lambda x: prefecture(x))
#df['都道府県名'] = df['所在地'].apply(lambda x: prefecture(x))
df
# Out:
# 47
#       株式コード ＥＤＩＮＥＴコード 上場区分 連結の有無        資本金                  提出者名  \
# 0    1301.T    E00012   上場     有     5664.0                株式会社極洋
# 1    1605.T    E00043   上場     有   290809.0             株式会社ＩＮＰＥＸ
# 2    1925.T    E00048   上場     有   161699.0           大和ハウス工業株式会社
# 3    1802.T    E00055   上場     有    57752.0               株式会社大林組
# 4    1812.T    E00058   上場     有    81447.0              鹿島建設株式会社
# 5    1928.T    E00143   上場     有   202591.0             積水ハウス株式会社
# 6    1860.T    E00147   上場     有    23001.0              戸田建設株式会社
# 7    1878.T    E00218   上場     有    29060.0              大東建託株式会社
# 8    2002.T    E00346   上場     有    17117.0        株式会社日清製粉グループ本社
# 9    2503.T    E00395   上場     有   102045.0       キリンホールディングス株式会社
# 10   2267.T    E00406   上場     有    31117.0            株式会社ヤクルト本社
# 11   2801.T    E00435   上場     有    11599.0            キッコーマン株式会社
# 12   2802.T    E00436   上場     有    79863.0               味の素株式会社
# ...

# %%
prefs = df['都道府県名'].tolist()
locs = df['所在地'].tolist()
for index,pref in enumerate(prefs):
    if pref==None:
        print(locs[index])
        print(index)
# Out:
# 北佐久郡御代田町大字御代田４１０６番地７３
# 66
# 京都市下京区塩小路通堀川東入南不動堂町８０１番地
# 74
# 門真市大字門真１００６番地
# 77
# 札幌市北区新琴似７条１丁目２番３９号
# 123
# 札幌市東区北２４条東２０丁目１番２１号
# 131
# 佐賀市本庄町１
# 207

# %%
df.to_csv("basic_info_pref.csv")
